# %% [markdown]
# $$ {\huge \text{ Disciplina: Logica Fuzzy }}\\  \\  \text{ Métodos SUGENO e  TSUKAMOTO }\\
# \ \  \ \ \ \
# \\
#  { \it  \text{ Discente: Prof. Dr. João Fernando }  }
#  \\
# \text{ Monitor: Arnaldo Araújo} \\
# \text{ Mestrado e Doutorado em Ciências da Computação - UFC }$$

# %%
#importar os pacotes necessários
import numpy as np
import skfuzzy as fuzz
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.font_manager import FontProperties
# %matplotlib inline

# %% [markdown]
# $$ \Large{\text{Método SUGENO de Defuzzificação}}$$

# %% [markdown]
# <img src="Images/Sugeno.png">

# %%
valores = np.arange(-5,5,0.1)
X1 = fuzz.sigmf(valores,0,-2.5) #função Sigmoide
X2 = fuzz.sigmf(valores,0,2.5)
fig,ax = plt.subplots()
ax.plot(valores,X1,'m',linewidth=3,label= 'Small')
ax.plot(valores,X2,'y',linewidth=3,label='Large') 
ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Valores da Variavel de Entrada')
ax.set_ylim(-0.05, 1.05);
ax.grid(True)
ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()

# %%
Y1 = fuzz.sigmf(valores,0,-0.5) #função Sigmoide
Y2 = fuzz.sigmf(valores,0,0.5)
fig,ax = plt.subplots()
ax.plot(valores,Y1,'r',linewidth=3,label= 'Small')
ax.plot(valores,Y2,'g',linewidth=3,label='Large') 
ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Valores da Variavel de Entrada')
ax.set_ylim(-0.05, 1.05);
ax.grid(True)
ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()

# %% [markdown]
# $$\Large{\text{ IF X is small and Y is small, THEN z = -x+y+1}\\
#  \text{IF X is small and Y is large,THEM z = -y+3 }\\
# \text{IF X is large and Y is small, THEN z = -x+3}\\
# \text{IF X is large and Y is large, THEN z = x+y+2}}$$

# %% [markdown]
# $$\Large{\textit{O modo de ativação da regra é o mesmo modelo do MAMDAMI -  MAXMIN / MAXPROD}}$$

# %%
#utilizando o mínimo 

x = -2.4  #posição 23 do vetor 
y = 1.6  #posição  65 do vetor
#regra1
w1 = min(X1[23],Y1[65])
w2 = min(X1[23],Y2[65])
w3 = min(X2[23],Y1[65])
w4 = min(X2[23],Y2[65])
z1 = -x+y+1
z2 = -y+3
z3= -x+3
z4 = x+y+2
Zfinal = (z1*w1)+(z2*w2)+(z3*w3)+(z4*w4)/(w1+w2+w3+w4)

# %%
Zfinal
# Out:
# 2.5626721757679118

# %% [markdown]
# $$ \Large{\text{Método TSUKAMOTO de Defuzzificação}}$$

# %% [markdown]
# <img src="Images/TSUKAMOTO.png">

# %%
intervaloX = np.arange(-10,10.1,0.1)
intervaloY = np.arange(0,10.1,0.1)
Small = fuzz.gaussmf(intervaloX,-10,5.5) #função Sigmoide
Medium = fuzz.gaussmf(intervaloX,0,3.5)
Large = fuzz.gaussmf(intervaloX,10,5.5)
fig,ax = plt.subplots()
ax.plot(intervaloX,Small,'r',linewidth=3,label= 'Small')
ax.plot(intervaloX,Medium,'g',linewidth=3,label='Medium')
ax.plot(intervaloX,Large,'b',linewidth=3,label='Large')

ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Valores da Variavel de Entrada')
ax.set_ylim(-0.05, 1.05);
ax.grid(True)
ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()

# %%
C1 = fuzz.trapmf(intervaloY,[0,2,10,10])
C2 = fuzz.trapmf(intervaloY,[0,0,4.5,6])
C3 = fuzz.trapmf(intervaloY,[7.4,10,10,10])
fig,ax = plt.subplots()
ax.plot(intervaloY,C1,'b',linewidth=3,label= 'Small')
ax.plot(intervaloY,C2,'g--',linewidth=3,label='Medium')
ax.plot(intervaloY,C3,'m*',linewidth=3,label='Large')

ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Valores da Variavel de Saída')
ax.set_ylim(-0.05, 1.05);
ax.grid(True)
ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()

# %% [markdown]
# $$\Large{\text{ IF X is small , THEN Y is C1}\\
#  \text{IF X is medium,THEM z is C2 }\\
# \text{IF X is large, THEN z is C3}\\}$$

# %% [markdown]
# $$\Large{\textit{O modo de ativação da regra é o mesmo modelo do MAMDAMI -  MAXMIN / MAXPROD}\\X = 4,8}$$

# %%
#função para achar a posição
def posicao(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]

# %%
w1 = Small[47]
w2 = Medium[47]
w3 = Large[47]
p1 = posicao(C1,w1)
p2 = posicao(C2,w2)
p3 = posicao(C3,w3)
P1 = np.where(C1 ==p1 )   
D1 = P1[0][0]
P2 = np.where(C2 ==p2 )   
D2 = P2[0][0]
P3 = np.where(C3 ==p3 )   
D3 = P3[0][0]

# %%
Zfinal = ( w1* D1/10 ) + (w2*D2/10) + (w3*D3/10) / (w1+w2+w3)
Zfinal
# Out:
# 1.0673397549511405

# %%
def achaVizinho(array,value):
    idx = np.searchsorted(array, value, side="left")
    if idx > 0 and (idx == len(array) or math.fabs(value - array[idx-1]) < math.fabs(value - array[idx])):
        return array[idx-1]
    else:
        return array[idx]
