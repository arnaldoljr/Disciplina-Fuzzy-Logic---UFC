# %% [markdown]
# $$ {\huge \text{ Disciplina: Lógica Fuzzy }}\\  \\  \large{\text{AULA 2.2 -  Composições Fuzzy }}\\
# \ \  \ \ \ \
# \\
#  { \it  \text{ Discente: Prof. Dr. João Fernando }  }
#  \\
# \text{ Monitor: Arnaldo Araújo} \\
# \text{ Mestrado e Doutorado em Ciências da Computação - UFC }$$

# %% [markdown]
# # Aula de Exercícios -  Scikit-Fuzzy -  questao 4.3

# %% [markdown]
# ![Captura%20de%20Tela%202017-09-18%20a%CC%80s%2022.25.17.png](attachment:Captura%20de%20Tela%202017-09-18%20a%CC%80s%2022.25.17.png)

# %%
#importar os pacotes necessários
import numpy as np
import skfuzzy as fuzz
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.font_manager import FontProperties
# %matplotlib inline

# %%
X = np.arange(0.0, 6.0, 1) #intervalo da variável temperatura
valores=[]
valores = list(range(6))
A = []
B = []
C = []

# %%
for i in valores:
    k=abs(X[i])
    A.append(1/(1+(5*((k-5)**2))))
    
for i in valores:
    k=abs(X[i])
    B.append(2**(-k))
    
for i in valores:
    k=abs(X[i])
    C.append(2*k/(k+5))

# %%
A = np.array(A)
B = np.array(B)
C = np.array(C)

# %%
A
# Out:
# array([ 0.00793651,  0.01234568,  0.02173913,  0.04761905,  0.16666667,  1.        ])

# %%
B
# Out:
# array([ 1.     ,  0.5    ,  0.25   ,  0.125  ,  0.0625 ,  0.03125])

# %%
C
# Out:
# array([ 0.        ,  0.33333333,  0.57142857,  0.75      ,  0.88888889,  1.        ])

# %%
fig,ax = plt.subplots()
ax.plot(X,A,'b--',linewidth=3,label='Funcao A')
ax.plot(X,B,'r--',linewidth=3,label='Funcao B')
ax.plot(X,C,'k--',linewidth=3,label='Funcao C')

ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Intervalo da Variavel X')
ax.set_ylim(-0.05, 1.05);

ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()

# %%
#Realizar o Lambda Cut para 0.2 - 0.6 - 0.9 - 1.0 

Cut1A = fuzz.arglcut(A, 0.2)
Cut1B = fuzz.arglcut(B, 0.2)
Cut1C = fuzz.arglcut(C, 0.2)

Cut2A = fuzz.arglcut(A, 0.6)
Cut2B = fuzz.arglcut(B, 0.6)
Cut2C = fuzz.arglcut(C, 0.6)

Cut3A = fuzz.arglcut(A, 0.9)
Cut3B = fuzz.arglcut(B, 0.9)
Cut3C = fuzz.arglcut(C, 0.9)

Cut4A = fuzz.arglcut(A, 1.0)
Cut4B = fuzz.arglcut(B, 1.0)
Cut4C = fuzz.arglcut(C, 1.0)

# %%
print('corte para 0.2')
print(Cut1A)
print(Cut1B) 
print (Cut1C)
# Out:
# corte para 0.2
# (array([5]),)
# (array([0, 1, 2]),)
# (array([1, 2, 3, 4, 5]),)

# %%
A[2]
# Out:
# 1.0

# %%
A[1]
# Out:
# 0.012345679012345678

# %%
print('corte para 0.6')
print(Cut2A) 
print(Cut2B) 
print(Cut2C)
# Out:
# corte para 0.6
# (array([5]),)
# (array([0]),)
# (array([3, 4, 5]),)

# %%
print('corte para 0.9')
print(Cut3A) 
print(Cut3B) 
print(Cut3C)
# Out:
# corte para 0.9
# (array([5]),)
# (array([0]),)
# (array([5]),)

# %%
print ('corte para 1.0')
print (Cut4A) 
print (Cut4B) 
print (Cut4C)
# Out:
# corte para 1.0
# (array([5]),)
# (array([0]),)
# (array([5]),)

# %%
B[0]
# Out:
# 1.0

# %% [markdown]
# ## Explorando um pouco mais.

# %%
R1 =  fuzz.fuzzy_or(X, A, X, B)
R2 =  fuzz.fuzzy_or(R1[0], R1[1], X, C)

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(122)
hax = fig.add_subplot(121)


ax.plot(X,A,'b--',linewidth=3,label='Funcao A')
ax.plot(X,B,'r--',linewidth=3,label='Funcao B')
ax.plot(X,C,'c--',linewidth=3,label='Funcao C')
ax.plot(R1[0],R1[1],'m',linewidth=5,label='Fuzzy Or(A,B)')
ax.plot(R2[0],R2[1],'y',linewidth=5,label='Fuzzy Or((A,B),C)')


ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Intervalo da Variavel X')
ax.set_ylim(-0.05, 1.05);




ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))


hax.plot(X,A,'b--',linewidth=3,label='Funcao A')
hax.plot(X,B,'r--',linewidth=3,label='Funcao B')
hax.plot(X,C,'c--',linewidth=3,label='Funcao C')
#hax.plot(R1[0],R1[1],'m',linewidth=5,label='Fuzzy Or(A,B)')
#hax.plot(R2[0],R2[1],'y',linewidth=5,label='Fuzzy Or((A,B),C)')


hax.set_ylabel('grau de pertinencia')
hax.set_xlabel('Intervalo da Variavel X')
hax.set_ylim(-0.05, 1.05);




#hax.legend(loc='upper right')
#hax.legend(bbox_to_anchor=(1.60, 1.15))

plt.show()

# %% [markdown]
# ## Questão 4.9

# %% [markdown]
# ![Captura%20de%20Tela%202017-09-18%20a%CC%80s%2022.39.18.png](attachment:Captura%20de%20Tela%202017-09-18%20a%CC%80s%2022.39.18.png)

# %% [markdown]
# Aço preparado por uma mistura composto de Manganês, Ferro e Carbono.
#
# Duas Proporções A1 e A2.

# %%
Z = np.arange(0.0, 7, 1) #interlavo da variável Z (quilos)
A1 = fuzz.trimf(Z,[0,3,4])
A2 = fuzz.trapmf(Z,[2,3,5,6])

# %%
Z
# Out:
# array([ 0.,  1.,  2.,  3.,  4.,  5.,  6.])

# %%
A1
# Out:
# array([ 0.        ,  0.33333333,  0.66666667,  1.        ,  0.        ,
#         0.        ,  0.        ])

# %%
A2
# Out:
# array([ 0.,  0.,  0.,  1.,  1.,  1.,  0.])

# %%
#Preciso setar os campos A2[3]-A2[5] com 0.5
A2[3] = 0.5
A2[4] = 0.5
A2[5] = 0.5

# %%
A2
# Out:
# array([ 0. ,  0. ,  0. ,  0.5,  0.5,  0.5,  0. ])

# %%
fig,ax = plt.subplots()
ax.plot(Z,A1,'b--',linewidth=3,label='Mistura A1')


ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Intervalo da Variavel Z')
ax.set_ylim(-0.05, 1.05);
ax.set_xlim(-0.05,6.05)
ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()





fig,ax = plt.subplots()
ax.plot(Z,A2,'r--',linewidth=3,label='Mistura A2')


ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Intervalo da Variavel Z')
ax.set_ylim(-0.05, 1.05);
ax.set_xlim(-0.05,6.25);
ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()

# %%
R49 = fuzz.fuzzy_or(Z,A1,Z,A2)

# %%
fig,ax = plt.subplots()
ax.plot(R49[0],R49[1],'k',linewidth=5,label='Mistura A1 e A2')


ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Intervalo da Variavel Z')
ax.set_ylim(-0.05, 1.05);
ax.set_xlim(-0.05,6.25);
ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()

# %%
#calculando a deffuzificação pela média ponderada 
k = fuzz.trimf(Z,[0,1,2])
for i in range(7):
    k[i] =  ( R49[0][i]*R49[1][i])

# %%
k
# Out:
# array([ 0.        ,  0.33333333,  1.33333333,  3.        ,  2.        ,
#         2.5       ,  0.        ])

# %%
sum(k)/sum(R49[1]) #axvline(x=3.0555555555555554)
# Out:
# 3.0555555555555554

# %%
fig,ax = plt.subplots()
ax.plot(R49[0],R49[1],'k',linewidth=5,label='Mistura A1 e A2')
plt.axvline(x=3.0555)



ax.set_ylabel('grau de pertinencia')
ax.set_xlabel('Intervalo da Variavel Z')
ax.set_ylim(-0.05, 1.05);
ax.set_xlim(-0.05,6.25);
ax.legend(loc='upper right')
ax.legend(bbox_to_anchor=(1.60, 1.15))
plt.show()

# %%
defuzz_centroid = fuzz.defuzz(R49[0], R49[1], 'centroid')  # Same as skfuzzy.centroid
defuzz_bisector = fuzz.defuzz(R49[0], R49[1], 'bisector')
defuzz_mom = fuzz.defuzz(R49[0], R49[1], 'mom')
defuzz_som = fuzz.defuzz(R49[0], R49[1], 'som')
defuzz_lom = fuzz.defuzz(R49[0], R49[1], 'lom')

# Collect info for vertical lines
labels = ['centroide', 'bissetriz', 'media dos maximos', 'minimo dos maximos',
          'maximo dos maximos']
xvals = [defuzz_centroid,
         defuzz_bisector,
         defuzz_mom,
         defuzz_som,
         defuzz_lom]
colors = ['r', 'b', 'g', 'c', 'm']
ymax = [fuzz.interp_membership(R49[0], R49[1], i) for i in xvals]

# Display and compare defuzzification results against membership function
plt.figure(figsize=(8, 5))

plt.plot(R49[0], R49[1], 'k')
for xv, y, label, color in zip(xvals, ymax, labels, colors):
    plt.vlines(xv, 0, y, label=label, color=color)
    
#plt.axvline(x=3.0555)
plt.ylabel('Fuzzy membership')
plt.xlabel('Universe variable (arb)')
plt.ylim(-0.01, 1.1)
plt.legend(loc=2)

plt.show()
